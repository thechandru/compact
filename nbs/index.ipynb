# %%
#| hide
from compact.core import *
from compact import lisp

# %% [markdown]
# # compact
#
# > Embed Scheme code inside python

# %% [markdown]
# Lisp is well-suited for symbolic computation. Since it represents code and data identically (homoiconicity), it makes it trivial to embed problem-specific semantics and language inside a Lisp program. Lisp programs manipulate (evaluate and apply) lists. Since Lisp programs are themselves lists, they can "rewrite themselves".
#
# Languages are limited by their syntax. For instance, if you wanted to introduce a new construct, it is usually clumsy to add new constructs into the language. However, because of the way Lisp handles symbols, adding a new form is just "business as usual" in Lisp.
#
# Lisp seems to strongly suggest expressing the program in language that is precise for the problem being solved. So if you don't have suitable nouns or verbs, just make them up and extend the language!

# %% [markdown]
# Scheme is a dialect of Lisp. There is disagreement on the direction of Lisp variants (mostly across Common Lisp and Scheme). We prefer Scheme because it has a simpler symbol model (the tl;dr is that in Common Lisp, functions live in different namespaces than variables, in Scheme they are the same).

# %% [markdown]
# ## What is compact

# %% [markdown]
# ::: {.callout-note}
#
# **compact** /ˈkäm-ˌpakt/
#
# *verb*
#
# 1. exert force on something so that it becomes more dense; compress
# 2. make or enter into a formal agreement with another party or parties
#
# *noun*
#
# 1. something that is compact or compacted
# 2. an agreement or covenant between two or more parties
#
# :::

# %% [markdown]
# The goal of `compact` is to provide a very simple mechanism for Python programmers to take advantage of Lisp inside their code without fighting multi-language problems. `compact` is a derivative of Scheme. However, this is not a dogmatic implementation that attempts to comply with standards like R5RS, R7RS (small v. large).
#
# A Python program can use Lisp by importing the `lisp` singleton and evaluating Lisp code through it.

# %%
from compact import lisp

# %%
"(/ 22.0 7)" @ lisp
# Out:
# 3.142857142857143

# %% [markdown]
# `"(expr)" @ lisp` evaluates a Lisp expression against the calling Python frame's globals — Python variables are visible in Lisp, and anything `define`d in Lisp lands back in Python as a regular variable. Python functions are callable from Lisp directly; Lisp functions are callable from Python.

# %%
a, b = 3, 4
"(define c (sqrt (+ (* a a) (* b b))))" @ lisp
c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 a, b = 3, 4
# ----> 2 "(define c (sqrt (+ (* a a) (* b b))))" @ lisp
#       3 c
#
# File ~/compact/compact/core.py:157, in LispCtx.__rmatmul__(self, s)
#     155 exprs = parse_all(s)
#     156 expr = exprs[0] if len(exprs) == 1 else [Symbol("begin")] + exprs
# --> 157 return scm_eval_tco(expr, self.env, self.sfs)
#
# File ~/compact/compact/core.py:85, in scm_eval_tco(expr, env, sfs)
#      83 "eval but with tail call optimization"
#      84 while True:
# ---> 85     r = scm_eval_one_step(expr, env, sfs)
#      86     if isinstance(r, Thunk): expr, env = r.expr, r.env
#      87     else: return r
#
# File ~/compact/compact/core.py:75, in scm_eval_one_step(expr, env, sfs)
#      72 # lists
#      73 hd, body = expr[0], expr[1:]
# ---> 75 if isinstance(hd, Symbol) and hd.s in sfs: return sfs[hd.s](body, env, sfs)
#      76 fn = scm_eval_tco(hd, env, sfs)
#      77 if isinstance(fn, Macro): return Thunk(fn.fn(*body), env)
#
# File ~/compact/compact/core.py:203, in _sf_define(xs, env, sfs)
#     201     return sym.s
#     202 arg0, *rest = xs
# --> 203 if isinstance(arg0, Symbol): return _mkfn(arg0, _body_expr(rest))
#     204 if isinstance(arg0, list): return _mkfn(arg0[0], [Symbol("lambda"), arg0[1:]] + rest)
#
# File ~/compact/compact/core.py:200, in _sf_define.<locals>._mkfn(sym, expr)
#     198 if not isinstance(sym, Symbol): raise SyntaxError(f"{sym} must be a symbol")
#     199 if env.is_primitive(sym.s): raise SyntaxError(f"cannot redefine primitive '{sym.s}'")
# --> 200 env[sym.s] = scm_eval_tco(expr, env, sfs)
#     201 return sym.s
#
# File ~/compact/compact/core.py:85, in scm_eval_tco(expr, env, sfs)
#      83 "eval but with tail call optimization"
#      84 while True:
# ---> 85     r = scm_eval_one_step(expr, env, sfs)
#      86     if isinstance(r, Thunk): expr, env = r.expr, r.env
#      87     else: return r
#
# File ~/compact/compact/core.py:76, in scm_eval_one_step(expr, env, sfs)
#      73 hd, body = expr[0], expr[1:]
#      75 if isinstance(hd, Symbol) and hd.s in sfs: return sfs[hd.s](body, env, sfs)
# ---> 76 fn = scm_eval_tco(hd, env, sfs)
#      77 if isinstance(fn, Macro): return Thunk(fn.fn(*body), env)
#      79 return scm_apply(fn, [scm_eval_tco(o, env, sfs) for o in body])
#
# File ~/compact/compact/core.py:85, in scm_eval_tco(expr, env, sfs)
#      83 "eval but with tail call optimization"
#      84 while True:
# ---> 85     r = scm_eval_one_step(expr, env, sfs)
#      86     if isinstance(r, Thunk): expr, env = r.expr, r.env
#      87     else: return r
#
# File ~/compact/compact/core.py:69, in scm_eval_one_step(expr, env, sfs)
#      67 "eval-uate lisp expressions given an environment and handlers for special forms"
#      68 # Atoms
# ---> 69 if isinstance(expr, Symbol): return env[expr.s]
#      70 if not isinstance(expr, list): return expr
#      72 # lists
#
# File ~/compact/compact/core.py:28, in Env.__getitem__(self, k)
#      26     if k in s.primitives: return s.primitives[k]
#      27     return s.d[k]
# ---> 28 raise KeyError(k)
#
# KeyError: 'sqrt'

# %% [markdown]
# One stated barrier to wider adoption of Lisp is limited library availability (say, compared to Python). `compact` sidesteps the library problem by embedding Lisp inside Python via a shared namespace. Specifically, `compact` shares the calling module's globals().

# %%
import math
pi = math.pi
"(define (area r) (* pi r r))" @ lisp
sorted(map(area, [1, 2, 3, 4, 5]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import math
#       2 pi = math.pi
#       3 "(define (area r) (* pi r r))" @ lisp
# ----> 4 sorted(map(area, [1, 2, 3, 4, 5]))
#
# NameError: name 'area' is not defined

# %% [markdown]
# Since Lisp programs rely heavily on recursion, it is common to implement _Tail Call Optimization_ (TCO). This effectively converts tail-recursive calls into an iteration, avoiding stack overflow.

# %%
"""
(define (factorial n acc)
  (if (= n 0) acc
      (factorial (- n 1) (* n acc))))
""" @ lisp
factorial(10000, 1)

# %% [markdown]
# As mentioned earlier, one of the powerful aspects of Lisp is the ability to invent syntax. A good example is looping constructs - by default we don't provide any. If you needed a special form of iterator, you could implement it as a Lisp macro and it would be indistinguishable from the rest of the language.

# %%
"""
  (define while
    (macro (cond . body)
      `(let loop () (when ,cond ,@body (loop)))))
""" @ lisp

"""
  (let ((i 0) (acc 0))
    (while (< i 5)
      (set! acc (+ acc i))
      (set! i (+ i 1)))
    acc) 
""" @ lisp

# %% [markdown]
# ## Install
#
# ```sh
# pip install compact-scheme
# ```
